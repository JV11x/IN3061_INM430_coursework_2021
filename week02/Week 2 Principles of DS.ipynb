# %%
#EXERCISE 1
# importing libaries and dataframes

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ticket1 = pd.read_csv('passengerData.csv')
ticket2 = pd.read_excel("ticketPrices.xlsx", sheet_name= 0)

# %%
ticket1.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
ticket2.describe
# Out:
# <bound method NDFrame.describe of    TicketType  Fare
# 0           1    33
# 1           2    56
# 2           3    77
# 3           4    22
# 4           5    14
# 5           6    66
# 6           7    87
# 7           8    36>

# %%
# STEP 2
# Using merge function to join ticket datasets

jointick = pd.merge(ticket1, ticket2)
jointick
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                                 Rice, Master. Eugene    male   2.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# ..                                                 ...     ...   ...
# ...

# %%
#STEP 3
# Finding oldest ticket buyer, and printing their name and age

maxtickage = jointick['Age'].max()

nameage = jointick['Name'][jointick.Age == maxtickage]
print(nameage, maxtickage)
# Out:
# 747    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object 80.0

# %%
# STEP 4
# Plotting scatter of age 'Age' v 'Fare' columns. 
import matplotlib.pyplot as plt

plt.scatter(jointick['Age'], jointick['Fare'])
plt.title('Age vs Ticket Price')
plt.show()

# %%
# split tickets by gender
FemaleTick = jointick.loc[(jointick['Sex'] == 'female')]

print(FemaleTick)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              9         1       3
# 3             25         0       3
# 4             33         1       3
# 5             41         0       3
# 7             57         1       2
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# 5       Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 7                                    Rugg, Miss. Emily  female  21.0
# ..                                                 ...     ...   ...
# ...

# %%
# Further split by age
A4050 = FemaleTick4050.loc[(FemaleTick['Age'] >= 40) & (FemaleTick['Age'] <= 50)]

print(A4050)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 # Further split by age
# ----> 2 A4050 = FemaleTick4050.loc[(FemaleTick['Age'] >= 40) & (FemaleTick['Age'] <= 50)]
#       4 print(A4050)
#
# NameError: name 'FemaleTick4050' is not defined

# %%
# STEP 5
# Plot new split groups
plt.scatter(A4050['Age'], A4050['Fare'])
plt.title('Age vs Ticket Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 # STEP 5
#       2 # Plot new split groups
# ----> 3 plt.scatter(A4050['Age'], A4050['Fare'])
#       4 plt.title('Age vs Ticket Price')
#       5 plt.show()
#
# NameError: name 'A4050' is not defined

# %%
#EXERCISE 2
#STEP 1
# Loading Titanic Dataset
TS = pd.read_csv('titanicSurvival_m.csv')
TS
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# STEP 2
# Check summary of missing plots
TS.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare            46
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# STEP 3
TS.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  845.000000
# mean     0.381594   32.304319
# std      0.806057   49.792612
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.275000
# max      6.000000  512.329200

# %%
# STEP 4
# Using fillna, missing values are replaces with 0

TS0 = TS.fillna(0)
TS0.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# STEP 5
# Using fillna missing values are replaced with the mean values for 'Age' & 'Fare' columns.  

TSCM =  TS.fillna(TS.mean()["Age":"Fare"])
TSCM.isna().sum()
# Out:
# C:\Users\jvernon\AppData\Local\Temp\ipykernel_10956\3725666358.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   TSCM =  TS.fillna(TS.mean()["Age":"Fare"])
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Standard deviation falls slightly by replacing NaN values with mean values
TSCM.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.304319
# std      0.806057   48.488766
# min      0.000000    0.000000
# 25%      0.000000    7.925000
# 50%      0.000000   15.500000
# 75%      0.000000   32.304319
# max      6.000000  512.329200

# %%
# Plotting different fillna approaches
plt.subplot(221)
plt.title('fillna 0')
plt.scatter(TS0['Age'],TS0['Fare'], s=5, alpha=0.2)

plt.subplot(222)
plt.title('fillna mean')
plt.scatter(TSCM['Age'],TSCM['Fare'], s=5, alpha=0.2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# STEP 6
# The aggregation to zero caused by the fillna 0 function, has cause a significant aggregation of plots towards the bottom of the chart. Conversly we see an aggregation of plots around the mean age of 29, the same degree of aggregation hasn't tkane place for the 'fare' varriable because there we're fewer missing plots in the intial instance.

# %%
# EXERCISE 3
# STEP 1
# Check dataset summary
WHO = pd.read_csv("TB_burden_countries_2014-09-29(1).csv")
WHO.describe()
# Out:
#        iso_numeric         year     e_pop_num  e_prev_100k  e_prev_100k_lo  \
# count  4903.000000  4903.000000  4.903000e+03  4892.000000     4892.000000
# mean    433.487457  2001.042219  2.899179e+07   207.694422       93.683299
# std     255.202944     6.643548  1.177827e+08   269.720954      138.015090
# min       4.000000  1990.000000  1.129000e+03     0.260000        0.080000
# 25%     212.000000  1995.000000  5.508830e+05    25.000000       10.000000
# 50%     430.000000  2001.000000  5.140332e+06    93.000000       37.000000
# 75%     646.000000  2007.000000  1.732282e+07   306.000000      129.250000
# max     894.000000  2012.000000  1.377065e+09  1860.000000     1316.000000
#
#        e_prev_100k_hi    e_prev_num  e_prev_num_lo  e_prev_num_hi  \
# count     4892.000000  4.892000e+03   4.892000e+03   4.892000e+03
# mean       378.137001  6.914368e+04   4.366106e+04   1.064607e+05
# std        501.059424  3.304527e+05   2.729764e+05   4.152786e+05
# ...

# %%
# Check missing varriables
WHO.isna().sum()
# Out:
# country                        0
# iso2                          23
# iso3                           0
# iso_numeric                    0
# g_whoregion                    0
# year                           0
# e_pop_num                      0
# e_prev_100k                   11
# e_prev_100k_lo                11
# e_prev_100k_hi                11
# e_prev_num                    11
# e_prev_num_lo                 11
# e_prev_num_hi                 11
# e_mort_exc_tbhiv_100k          1
# e_mort_exc_tbhiv_100k_lo       1
# e_mort_exc_tbhiv_100k_hi       1
# e_mort_exc_tbhiv_num           1
# e_mort_exc_tbhiv_num_lo        1
# e_mort_exc_tbhiv_num_hi        1
# source_mort                    1
# e_inc_100k                     1
# e_inc_100k_lo                  1
# e_inc_100k_hi                  1
# e_inc_num                      1
# e_inc_num_lo                   1
# e_inc_num_hi                   1
# e_tbhiv_prct                1250
# e_tbhiv_prct_lo             1446
# ...

# %%
# STEP 2
#removing all columns where more than %10 of the data is missing 
WHO_null = WHO.isnull().sum() / len(WHO)
missing_features = WHO_null[WHO_null > 0.1].index
WHO.drop(missing_features, axis=1, inplace=True)

# %%
# using fillna to replace missing columns with mean values
WHOre = WHO.fillna(WHO.mean())
# Out:
# C:\Users\jvernon\AppData\Local\Temp\ipykernel_10956\3924095284.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   WHOre = WHO.fillna(WHO.mean())

# %%
WHOre.isna().sum()
# Out:
# country                      0
# iso2                        23
# iso3                         0
# iso_numeric                  0
# g_whoregion                  0
# year                         0
# e_pop_num                    0
# e_prev_100k                  0
# e_prev_100k_lo               0
# e_prev_100k_hi               0
# e_prev_num                   0
# e_prev_num_lo                0
# e_prev_num_hi                0
# e_mort_exc_tbhiv_100k        0
# e_mort_exc_tbhiv_100k_lo     0
# e_mort_exc_tbhiv_100k_hi     0
# e_mort_exc_tbhiv_num         0
# e_mort_exc_tbhiv_num_lo      0
# e_mort_exc_tbhiv_num_hi      0
# source_mort                  1
# e_inc_100k                   0
# e_inc_100k_lo                0
# e_inc_100k_hi                0
# e_inc_num                    0
# e_inc_num_lo                 0
# e_inc_num_hi                 0
# source_tbhiv                 1
# c_cdr                        0
# c_cdr_lo                     0
# c_cdr_hi                     0
# ...

# %%
# STEP 3
# Plotting Histograms of various earning metrics
plt.subplot(221)
plt.hist(WHOre['e_prev_100k_hi'])
plt.title('e_prev_100k_hi')
plt.subplot(222)
plt.title('e_prev_100k_lo')
plt.hist(WHOre['e_prev_100k_lo'])
plt.subplot(223)
plt.title('e_prev_100k')
plt.hist(WHOre['e_prev_100k'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# STEP 4
# Using a log function to reduce te histogram skew
E100kWHOre = np.log(WHOre['e_prev_100k'])
E100kloWHOre = np.log(WHOre['e_prev_100k_lo'])
E100khiWHOre = np.log(WHOre['e_prev_100k_hi'])

# %%
plt.subplot(221)
plt.hist(E100khiWHOre)
plt.title('e_prev_100k_hi')
plt.subplot(222)
plt.title('e_prev_100k_lo')
plt.hist(E100kloWHOre)
plt.subplot(223)
plt.title('e_prev_100k')
plt.hist(E100kWHOre)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Creating DF with only numeric values
WHON = WHOre.select_dtypes(include='number')

# %%
# STEP 5
# Normalising data so all values fall between 0 and 1 to make means easier to interept 
def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

SWHON = NormalizeData(WHON)

SWHON.describe()
# Out:
# C:\Users\jvernon\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
#        iso_numeric         year    e_pop_num  e_prev_100k  e_prev_100k_lo  \
# count  4903.000000  4903.000000  4903.000000  4903.000000     4903.000000
# mean      0.482570     0.501919     0.021053     0.111539        0.071131
# std       0.286745     0.301979     0.085532     0.144869        0.104763
# min       0.000000     0.000000     0.000000     0.000000        0.000000
# 25%       0.233708     0.227273     0.000399     0.013303        0.007538
# 50%       0.478652     0.500000     0.003732     0.049867        0.028056
# 75%       0.721348     0.772727     0.012579     0.164130        0.097969
# ...

# %%
# STEP 5
# Visualising means of columns
WM = SWHON.mean(axis=0)
WSD = SWHON.std(axis=0)

WM.plot(x="X", y=[], kind="bar")
# Out:
# <AxesSubplot:>

# %%
WSD.plot(x="X", y=[], kind="bar")
# Out:
# <AxesSubplot:>
