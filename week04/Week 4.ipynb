# %% [markdown]
# Exercise 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
import seaborn as sns
from scipy.stats import sem

from numpy.random import randn
from numpy.random import seed
from numpy import mean
from numpy import var
from math import sqrt

df = pd.read_csv('censusCrimeClean.csv')

df.describe()
# Out:
#               fold   population  householdsize  racepctblack  racePctWhite  \
# count  1994.000000  1994.000000    1994.000000   1994.000000   1994.000000
# mean      5.493982     0.057593       0.463395      0.179629      0.753716
# std       2.873694     0.126906       0.163717      0.253442      0.244039
# min       1.000000     0.000000       0.000000      0.000000      0.000000
# 25%       3.000000     0.010000       0.350000      0.020000      0.630000
# 50%       5.000000     0.020000       0.440000      0.060000      0.850000
# 75%       8.000000     0.050000       0.540000      0.230000      0.940000
# max      10.000000     1.000000       1.000000      1.000000      1.000000
#
#        racePctAsian  racePctHisp  agePct12t21  agePct12t29  agePct16t24  ...  \
# count   1994.000000  1994.000000  1994.000000  1994.000000  1994.000000  ...
# mean       0.153681     0.144022     0.424218     0.493867     0.336264  ...
# ...

# %%
corrM = df.corr()

# %%
plt.matshow(corrM)
plt.show()

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(corrM, fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
plt.
# Out:
#   Input In [17]
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
heatmap = sns.heatmap(corrM, annot=True, cmap="Blues", fmt='.1g')

# %%
perdf = st.pearsonr(df["medIncome"],df["ViolentCrimesPerPop"])
print(perdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 perdf = st.pearsonr(df["medIncome"],df["ViolentCrimesPerPop"])
#       2 print(perdf)
#
# NameError: name 'st' is not defined

# %%
spedf = st.spearmanr(df["medIncome"],df["ViolentCrimesPerPop"])
print(spedf)

# %%
plt.scatter(df["medIncome"],df["ViolentCrimesPerPop"])
plt.show
print(perdf,spedf)

# %%
plt.plot(spedf)
plt.show

# %%
plt.plot(perdf)
plt.show

# %%
plt.figure(figsize=(14,8))
sns.pairplot(df[['medIncome','ViolentCrimesPerPop']], kind="reg")

# %%
#Plots a Polynomial regression
sns.regplot(x=df["medIncome"], y=df["ViolentCrimesPerPop"])

# %% [markdown]
# Exercise 2

# %%
heart = pd.read_csv('heart.csv')
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart['sex'].replace(0, 'Female',inplace=True)
heart['sex'].replace(1, 'Male',inplace=True)

heart.rename(columns={'sex':'gender'}, inplace = True)

# %%
heart['target'].replace(0, 'Disease',inplace=True)
heart['target'].replace(1, 'Clear',inplace=True)
heart.rename(columns={'target':'hasHeartDisease'}, inplace = True)

heart
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    Male   3       145   233    1        0      150      0      2.3
# 1     37    Male   2       130   250    0        1      187      0      3.5
# 2     41  Female   1       130   204    0        0      172      0      1.4
# 3     56    Male   1       120   236    0        1      178      0      0.8
# 4     57  Female   0       120   354    0        1      163      1      0.6
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57  Female   0       140   241    0        1      123      1      0.2
# 299   45    Male   3       110   264    0        1      132      0      1.2
# 300   68    Male   0       144   193    1        1      141      0      3.4
# 301   57    Male   0       130   131    0        1      115      1      1.2
# 302   57  Female   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal hasHeartDisease
# ...

# %%
heart.describe()
# Out:
#               age          cp    trestbps        chol         fbs     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.966997  131.623762  246.264026    0.148515    0.528053
# std      9.082101    1.032052   17.538143   51.830751    0.356198    0.525860
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     47.500000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     55.000000    1.000000  130.000000  240.000000    0.000000    1.000000
# 75%     61.000000    2.000000  140.000000  274.500000    0.000000    1.000000
# max     77.000000    3.000000  200.000000  564.000000    1.000000    2.000000
#
#           thalach       exang     oldpeak       slope          ca        thal
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   149.646865    0.326733    1.039604    1.399340    0.729373    2.313531
# ...

# %%
print(heart.mean())
print(heart.std())
# Out:
# age          54.366337
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# dtype: float64
# age          9.082101
# cp           1.032052
# trestbps    17.538143
# chol        51.830751
# fbs          0.356198
# restecg      0.525860
# thalach     22.905161
# exang        0.469794
# oldpeak      1.161075
# slope        0.616226
# ca           1.022606
# thal         0.612277
# dtype: float64
# C:\Users\jvernon\AppData\Local\Temp\ipykernel_44304\1293775027.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(heart.mean())
# ...

# %%
haveHeart = heart.loc[(heart['hasHeartDisease'] == 'Disease')]
clearHeart = heart.loc[(heart['hasHeartDisease'] == 'Clear')]
haveHeart.describe()
# Out:
#               age          cp    trestbps        chol         fbs     restecg  \
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean    56.601449    0.478261  134.398551  251.086957    0.159420    0.449275
# std      7.962082    0.905920   18.729944   49.454614    0.367401    0.541321
# min     35.000000    0.000000  100.000000  131.000000    0.000000    0.000000
# 25%     52.000000    0.000000  120.000000  217.250000    0.000000    0.000000
# 50%     58.000000    0.000000  130.000000  249.000000    0.000000    0.000000
# 75%     62.000000    0.000000  144.750000  283.000000    0.000000    1.000000
# max     77.000000    3.000000  200.000000  409.000000    1.000000    2.000000
#
#           thalach       exang     oldpeak       slope          ca        thal
# count  138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean   139.101449    0.550725    1.585507    1.166667    1.166667    2.543478
# ...

# %%
print('mean heart rate of disease', haveHeart.trestbps.mean())
print('mean heart rate of clear',clearHeart.trestbps.mean())
print('stdv heart rate of disease', haveHeart.trestbps.std())
print('stdv heart rate of clear',clearHeart.trestbps.std())
# Out:
# mean heart rate of disease 134.3985507246377
# mean heart rate of clear 129.3030303030303
# stdv heart rate of disease 18.72994396158135
# stdv heart rate of clear 16.16961326687487

# %%
f, (ax1, ax2) = plt.subplots(ncols=2,sharey=True)
ax1.boxplot(haveHeart['trestbps'])
ax1.set_title('Have Heart BPS')
ax2.boxplot(clearHeart['trestbps'])
ax2.set_title('Clear Heart BPS')
# Out:
# Text(0.5, 1.0, 'Clear Heart BPS')

# %%
f, (ax1, ax2) = plt.subplots(ncols=2,sharey=True)
ax1.hist(haveHeart['trestbps'])
ax1.set_title('Have Heart BPS')
ax2.hist(clearHeart['trestbps'])
ax2.set_title('Clear Heart BPS')
# Out:
# Text(0.5, 1.0, 'Clear Heart BPS')

# %%
stats.ttest_ind(haveHeart['trestbps'],clearHeart['trestbps'])
# Out:
# Ttest_indResult(statistic=2.5412927171039, pvalue=0.011546059200233312)

# %%
# function to calculate Cohen's d for independent samples
def cohend(d1, d2):
# calculate the size of samples
    n1, n2 = len(d1), len(d2)
# calculate the variance of the samples
    s1, s2 = var(d1, ddof=1), var(d2, ddof=1)
# calculate the pooled standard deviation
    s = sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
# calculate the means of the samples
    u1, u2 = mean(d1), mean(d2)
# calculate the effect size
    return (u1 - u2) / s

# %%
cohend(haveHeart['trestbps'],clearHeart['trestbps'])
# Out:
# 0.29315309981436166

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The effect size is relatively small

# %%
f, (ax1, ax2) = plt.subplots(ncols=2,sharey=True)
ax1.boxplot(haveHeart['chol'])
ax1.set_title('Have Heart col')
ax2.boxplot(clearHeart['chol'])
ax2.set_title('Clear Heart col')
# Out:
# Text(0.5, 1.0, 'Clear Heart col')

# %%
f, (ax1, ax2) = plt.subplots(ncols=2,sharey=True)
ax1.hist(haveHeart['chol'])
ax1.set_title('Have Heart col')
ax2.hist(clearHeart['chol'])
ax2.set_title('Clear Heart col')
# Out:
# Text(0.5, 1.0, 'Clear Heart col')

# %%
stats.ttest_ind(haveHeart['chol'],clearHeart['chol'])
# Out:
# Ttest_indResult(statistic=1.4842450762526977, pvalue=0.13879032695600638)

# %%
cohend(haveHeart['chol'],clearHeart['chol'])
# Out:
# 0.17121642149257874

# %%
corrheart = heart.corr()
plt.matshow(corrheart)
plt.show()

# %%
heatmap = sns.heatmap(corrheart, annot=True, cmap="Blues", fmt='.1g')

# %% [markdown]
# Weak correlation across most varriables (although not accounting for the target varriable) suggests we're not likely to find a strong correlation between other

# %% [markdown]
# Exercise 3

# %%
hasDiseaseCount=heart[heart.hasHeartDisease=='Disease'].groupby("gender").count().hasHeartDisease

#Count the number of gender type
totalCount=heart.groupby("gender").count()['hasHeartDisease']

#combine into a dataframe (both are indexed with gender, so will be matched) and specify the columns
p=pd.concat([hasDiseaseCount, totalCount], axis=1)
p.columns = ["heartDiseaseCount", "totalCount"]

#create a new column and calculate the proportion
p['propHeartDisease']=p["heartDiseaseCount"]/p["totalCount"]

#print the results
print(p.head())
# Out:
#         heartDiseaseCount  totalCount  propHeartDisease
# gender
# Female                 24          96          0.250000
# Male                  114         207          0.550725

# %%
p
# Out:
#         heartDiseaseCount  totalCount  propHeartDisease
# gender
# Female                 24          96          0.250000
# Male                  114         207          0.550725

# %%
p_m = 114/207
p_m
# Out:
# 0.5507246376811594

# %%
n= 207

# %%
se_male = np.sqrt(p_m * (1 - p_m) / n)
print(se_male)
# Out:
# 0.0345731047302169

# %%
import statsmodels.api as sm
sm.stats.proportion_confint(n * p_m, n)
# Out:
# (0.4829625975762029, 0.618486677786116)

# %%
p_f = 24/96
p_f
# Out:
# 0.25

# %%
fn= 96

# %%
se_female = np.sqrt(p_f * (1 - p_f) / fn)
print(se_female)
# Out:
# 0.04419417382415922

# %%
import statsmodels.api as sm
sm.stats.proportion_confint(fn * p_m, fn)
# Out:
# (0.4512216711010406, 0.6502276042612782)

# %%
se_diff = np.sqrt(se_female**2 + se_male**2)
se_diff
# Out:
# 0.05611082400648334

# %%
d = 0.55 - 0.25
lcb = d - 1.96 * se_diff  #lower limit of the CI
ucb = d + 1.96 * se_diff  #upper limit of the CI

print( lcb, ucb)
# Out:
# 0.1900227849472927 0.4099772150527074
